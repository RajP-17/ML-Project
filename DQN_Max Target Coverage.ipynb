# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt  # For plotting the reward graph

# Check if a GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Hyperparameters
learning_rate = 0.001
gamma = 0.995
epsilon = 1.0   #Initial probability for taking a random (exploratory) action
epsilon_decay = 0.995   #As training proceeds, epsilon decreases (less exploration) until it hits a minimum threshold.
epsilon_min = 0.01
batch_size =  128
num_episodes = 400  # Number of episodes to train
memory = deque(maxlen=50000)
#try with shorter buffer size

#after go to ppl

# Dots distribution in the grid
dots = [
    [1.73, 2.91], [1.33, 2.80], [1.25, 0.83], [2.59, 2.91], [1.64, 1.15],
    [2.01, 2.17], [1.60, 1.70], [0.47, 2.05], [1.81, 1.96], [1.64, 1.28],
    [2.01, 1.86], [2.94, 1.07], [1.26, 2.92], [1.56, 1.29], [2.03, 2.67],
    [1.89, 2.02], [1.76, 0.98], [1.74, 2.00], [1.69, 2.01], [2.45, 1.56],
    [0.39, 2.64], [3.27, 2.07], [3.27, 3.89], [2.89, 2.60], [0.60, 3.20]
]

# %%
# Define the neural network for Q-value approximation
class QNetwork(nn.Module):      # nn.Model - inherited class - base class for all neural network modules in PyTorch.
    def __init__(self, input_size, output_size):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, 1024)  # fully connected linear layers
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, output_size)

        #try more options
        #

    def forward(self, state): # network architecture
        x = torch.relu(self.fc1(state))   #ReLU = Rectified Linear Unit
        x = torch.relu(self.fc2(x))
        return self.fc3(x)   # raw Q-value

# Initialize the environment (grid, disks, and dots)
class DiskEnvironment:
    def __init__(self, dots, grid_size=(4, 4), disk_radius=1.2):
        self.dots = np.array(dots)
        self.grid_size = grid_size
        self.disk_radius = disk_radius
        self.reset()

    def reset(self):
        # Reset the environment to initial positions
        self.disk1_pos = np.array([2.0, 2.0])  # Starting position of disk 1
        self.disk2_pos = np.array([2.0, 2.0])  # Starting position of disk 2
        return np.concatenate((self.disk1_pos, self.disk2_pos))

    def step(self, action):
        # Define the movement: 0 = stay, 1 = up, 2 = down, 3 = left, 4 = right
        movement = {
            0: np.array([0, 0]),
            1: np.array([0, 0.1]),
            2: np.array([0, -0.1]),
            3: np.array([-0.1, 0]),
            4: np.array([0.1, 0])
        }
        # Extract actions for both disks
        disk1_action = action // 5  # First disk's action
        disk2_action = action % 5   # Second disk's action

        # Update disk positions
        self.disk1_pos = np.clip(self.disk1_pos + movement[disk1_action], 0, 4)
        self.disk2_pos = np.clip(self.disk2_pos + movement[disk2_action], 0, 4)

        # Calculate reward
        reward = self.calculate_reward()

        # Return new state, reward, and done flag (if the episode ends)
        next_state = np.concatenate((self.disk1_pos, self.disk2_pos))
        done = False  # For simplicity, let's assume episodes don't have a fixed end
        return next_state, reward, done

    def calculate_reward(self):
        # Calculate how many dots are within the disks' coverage areas
        covered_dots = 0
        for dot in self.dots:
            if np.linalg.norm(dot - self.disk1_pos) <= self.disk_radius or np.linalg.norm(dot - self.disk2_pos) <= self.disk_radius:
                covered_dots += 1
        return covered_dots  # Reward is the number of covered dots


# Initialize Q-network and target network, and move them to the GPU if available
q_network = QNetwork(input_size=4, output_size=25).to(device)  # 4 inputs for the disk positions, 25 possible actions
target_network = QNetwork(input_size=4, output_size=25).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=learning_rate)
loss_fn = nn.MSELoss()

# Initialize the environment
env = DiskEnvironment(dots)

# Replay buffer for experience replay
memory = deque(maxlen=20000)

# Track rewards for each episode
episode_rewards = []

# Function to select action using epsilon-greedy policy
def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.randint(0, 24)  # Random action
    else:
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)  # Move state to GPU
        with torch.no_grad():
            q_values = q_network(state_tensor)
            return q_values.argmax().item()  # Action with max Q-value

# Store experiences in the replay buffer
def store_experience(memory, state, action, reward, next_state):
    memory.append((state, action, reward, next_state))

# Sample a batch from the memory
def sample_batch(memory, batch_size):
    return random.sample(memory, batch_size)

# Train the Q-network with a batch of experiences
# Each experience contains a state, the action taken, the reward received, and the next state.
def train_q_network():
    if len(memory) < batch_size:
        return  # Not enough samples to train

    batch = sample_batch(memory, batch_size)
    states, actions, rewards, next_states = zip(*batch)

    # Move states and actions to GPU   - Converting Python lists/tuples into PyTorch tensors
    states_tensor = torch.FloatTensor(states).to(device)
    actions_tensor = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards_tensor = torch.FloatTensor(rewards).to(device)
    next_states_tensor = torch.FloatTensor(next_states).to(device)

    # Compute current Q-values
    current_q_values = q_network(states_tensor).gather(1, actions_tensor)   #pick out the Q–value corresponding to the action that was actually taken in each experience.

    # Compute target Q-values
    with torch.no_grad():
        max_next_q_values = target_network(next_states_tensor).max(1)[0]
        target_q_values = rewards_tensor + gamma * max_next_q_values      #immediate reward plus the discounted maximum Q–value of the next state

    # Compute loss and backpropagate
    loss = loss_fn(current_q_values.squeeze(), target_q_values)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # The computed loss tells us how far our network’s predictions are from the target values.
    # We then use gradient descent (via backpropagation) to update the
    # network weights to minimize this error.

# %%
# Training loop for multiple episodes
for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0

    for step in range(100):
        action = select_action(state, epsilon)
        next_state, reward, done = env.step(action)
        store_experience(memory, state, action, reward, next_state)
        total_reward += reward
        state = next_state

        # Train the Q-network
        train_q_network()

        if done:
            break

    # Track the total reward for this episode
    episode_rewards.append(total_reward)

    # Decay epsilon
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

    # Print episode statistics
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}, Epsilon: {epsilon:.4f}")

    # Update target network weights
    if episode % 10 == 0:
        target_network.load_state_dict(q_network.state_dict())

print("Training completed!")

# Plot the episode vs reward graph
plt.plot(episode_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Episode vs Total Reward')
plt.show()
# Out:
# Episode 1/400, Total Reward: 1779, Epsilon: 0.9950
# <ipython-input-5-7a6a2e22be33>:108: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   states_tensor = torch.FloatTensor(states).to(device)
# Episode 2/400, Total Reward: 1960, Epsilon: 0.9900
# Episode 3/400, Total Reward: 1939, Epsilon: 0.9851
# Episode 4/400, Total Reward: 1863, Epsilon: 0.9801
# Episode 5/400, Total Reward: 1897, Epsilon: 0.9752
# Episode 6/400, Total Reward: 1816, Epsilon: 0.9704
# Episode 7/400, Total Reward: 1840, Epsilon: 0.9655
# Episode 8/400, Total Reward: 1911, Epsilon: 0.9607
# Episode 9/400, Total Reward: 1870, Epsilon: 0.9559
# Episode 10/400, Total Reward: 1763, Epsilon: 0.9511
# Episode 11/400, Total Reward: 1961, Epsilon: 0.9464
# Episode 12/400, Total Reward: 1922, Epsilon: 0.9416
# Episode 13/400, Total Reward: 1799, Epsilon: 0.9369
# Episode 14/400, Total Reward: 1925, Epsilon: 0.9322
# Episode 15/400, Total Reward: 1803, Epsilon: 0.9276
# Episode 16/400, Total Reward: 1873, Epsilon: 0.9229
# Episode 17/400, Total Reward: 1927, Epsilon: 0.9183
# Episode 18/400, Total Reward: 1881, Epsilon: 0.9137
# Episode 19/400, Total Reward: 1791, Epsilon: 0.9092
# Episode 20/400, Total Reward: 2035, Epsilon: 0.9046
# Episode 21/400, Total Reward: 1918, Epsilon: 0.9001
# Episode 22/400, Total Reward: 1916, Epsilon: 0.8956
# Episode 23/400, Total Reward: 2099, Epsilon: 0.8911
# Episode 24/400, Total Reward: 2102, Epsilon: 0.8867
# Episode 25/400, Total Reward: 1966, Epsilon: 0.8822
# Episode 26/400, Total Reward: 1959, Epsilon: 0.8778
# Episode 27/400, Total Reward: 1990, Epsilon: 0.8734
# Episode 28/400, Total Reward: 2056, Epsilon: 0.8691
# Episode 29/400, Total Reward: 2034, Epsilon: 0.8647
# Episode 30/400, Total Reward: 1635, Epsilon: 0.8604
# Episode 31/400, Total Reward: 1852, Epsilon: 0.8561
# Episode 32/400, Total Reward: 1899, Epsilon: 0.8518
# Episode 33/400, Total Reward: 1816, Epsilon: 0.8475
# Episode 34/400, Total Reward: 1891, Epsilon: 0.8433
# Episode 35/400, Total Reward: 1421, Epsilon: 0.8391
# Episode 36/400, Total Reward: 1883, Epsilon: 0.8349
# Episode 37/400, Total Reward: 1717, Epsilon: 0.8307
# Episode 38/400, Total Reward: 1949, Epsilon: 0.8266
# Episode 39/400, Total Reward: 1828, Epsilon: 0.8224
# Episode 40/400, Total Reward: 2109, Epsilon: 0.8183
# Episode 41/400, Total Reward: 2031, Epsilon: 0.8142
# Episode 42/400, Total Reward: 1906, Epsilon: 0.8102
# Episode 43/400, Total Reward: 1969, Epsilon: 0.8061
# Episode 44/400, Total Reward: 1969, Epsilon: 0.8021
# Episode 45/400, Total Reward: 1916, Epsilon: 0.7981
# Episode 46/400, Total Reward: 2128, Epsilon: 0.7941
# Episode 47/400, Total Reward: 1477, Epsilon: 0.7901
# Episode 48/400, Total Reward: 1975, Epsilon: 0.7862
# Episode 49/400, Total Reward: 1918, Epsilon: 0.7822
# Episode 50/400, Total Reward: 2066, Epsilon: 0.7783
# Episode 51/400, Total Reward: 1954, Epsilon: 0.7744
# Episode 52/400, Total Reward: 1784, Epsilon: 0.7705
# Episode 53/400, Total Reward: 2058, Epsilon: 0.7667
# Episode 54/400, Total Reward: 2018, Epsilon: 0.7629
# Episode 55/400, Total Reward: 2045, Epsilon: 0.7590
# Episode 56/400, Total Reward: 2087, Epsilon: 0.7553
# Episode 57/400, Total Reward: 1985, Epsilon: 0.7515
# Episode 58/400, Total Reward: 1806, Epsilon: 0.7477
# Episode 59/400, Total Reward: 2087, Epsilon: 0.7440
# Episode 60/400, Total Reward: 2027, Epsilon: 0.7403
# Episode 61/400, Total Reward: 2174, Epsilon: 0.7366
# Episode 62/400, Total Reward: 1934, Epsilon: 0.7329
# Episode 63/400, Total Reward: 2059, Epsilon: 0.7292
# Episode 64/400, Total Reward: 1925, Epsilon: 0.7256
# Episode 65/400, Total Reward: 2013, Epsilon: 0.7219
# Episode 66/400, Total Reward: 2084, Epsilon: 0.7183
# Episode 67/400, Total Reward: 1971, Epsilon: 0.7147
# Episode 68/400, Total Reward: 2165, Epsilon: 0.7112
# Episode 69/400, Total Reward: 2114, Epsilon: 0.7076
# Episode 70/400, Total Reward: 2053, Epsilon: 0.7041
# Episode 71/400, Total Reward: 2125, Epsilon: 0.7005
# Episode 72/400, Total Reward: 1878, Epsilon: 0.6970
# Episode 73/400, Total Reward: 1930, Epsilon: 0.6936
# Episode 74/400, Total Reward: 2129, Epsilon: 0.6901
# Episode 75/400, Total Reward: 1989, Epsilon: 0.6866
# Episode 76/400, Total Reward: 2090, Epsilon: 0.6832
# Episode 77/400, Total Reward: 2072, Epsilon: 0.6798
# Episode 78/400, Total Reward: 2106, Epsilon: 0.6764
# Episode 79/400, Total Reward: 2132, Epsilon: 0.6730
# Episode 80/400, Total Reward: 2158, Epsilon: 0.6696
# Episode 81/400, Total Reward: 2114, Epsilon: 0.6663
# Episode 82/400, Total Reward: 2069, Epsilon: 0.6630
# Episode 83/400, Total Reward: 2184, Epsilon: 0.6597
# Episode 84/400, Total Reward: 2185, Epsilon: 0.6564
# Episode 85/400, Total Reward: 2056, Epsilon: 0.6531
# Episode 86/400, Total Reward: 2136, Epsilon: 0.6498
# Episode 87/400, Total Reward: 2104, Epsilon: 0.6466
# Episode 88/400, Total Reward: 2035, Epsilon: 0.6433
# Episode 89/400, Total Reward: 2008, Epsilon: 0.6401
# Episode 90/400, Total Reward: 1980, Epsilon: 0.6369
# Episode 91/400, Total Reward: 2100, Epsilon: 0.6337
# Episode 92/400, Total Reward: 2036, Epsilon: 0.6306
# Episode 93/400, Total Reward: 2181, Epsilon: 0.6274
# Episode 94/400, Total Reward: 2197, Epsilon: 0.6243
# Episode 95/400, Total Reward: 2013, Epsilon: 0.6211
# Episode 96/400, Total Reward: 2190, Epsilon: 0.6180
# Episode 97/400, Total Reward: 2175, Epsilon: 0.6149
# Episode 98/400, Total Reward: 2189, Epsilon: 0.6119
# Episode 99/400, Total Reward: 2179, Epsilon: 0.6088
# Episode 100/400, Total Reward: 2123, Epsilon: 0.6058
# Episode 101/400, Total Reward: 2184, Epsilon: 0.6027
# Episode 102/400, Total Reward: 2110, Epsilon: 0.5997
# Episode 103/400, Total Reward: 2189, Epsilon: 0.5967
# Episode 104/400, Total Reward: 2191, Epsilon: 0.5937
# Episode 105/400, Total Reward: 2136, Epsilon: 0.5908
# Episode 106/400, Total Reward: 2148, Epsilon: 0.5878
# Episode 107/400, Total Reward: 2166, Epsilon: 0.5849
# Episode 108/400, Total Reward: 2166, Epsilon: 0.5820
# Episode 109/400, Total Reward: 2154, Epsilon: 0.5790
# Episode 110/400, Total Reward: 1984, Epsilon: 0.5762
# Episode 111/400, Total Reward: 2127, Epsilon: 0.5733
# Episode 112/400, Total Reward: 2145, Epsilon: 0.5704
# Episode 113/400, Total Reward: 2109, Epsilon: 0.5676
# Episode 114/400, Total Reward: 2223, Epsilon: 0.5647
# Episode 115/400, Total Reward: 2131, Epsilon: 0.5619
# Episode 116/400, Total Reward: 2174, Epsilon: 0.5591
# Episode 117/400, Total Reward: 2219, Epsilon: 0.5563
# Episode 118/400, Total Reward: 2188, Epsilon: 0.5535
# Episode 119/400, Total Reward: 2131, Epsilon: 0.5507
# Episode 120/400, Total Reward: 2234, Epsilon: 0.5480
# Episode 121/400, Total Reward: 2183, Epsilon: 0.5452
# Episode 122/400, Total Reward: 1964, Epsilon: 0.5425
# Episode 123/400, Total Reward: 2192, Epsilon: 0.5398
# Episode 124/400, Total Reward: 2211, Epsilon: 0.5371
# Episode 125/400, Total Reward: 2123, Epsilon: 0.5344
# Episode 126/400, Total Reward: 2175, Epsilon: 0.5318
# Episode 127/400, Total Reward: 2239, Epsilon: 0.5291
# Episode 128/400, Total Reward: 2211, Epsilon: 0.5264
# Episode 129/400, Total Reward: 2182, Epsilon: 0.5238
# Episode 130/400, Total Reward: 2194, Epsilon: 0.5212
# Episode 131/400, Total Reward: 2216, Epsilon: 0.5186
# Episode 132/400, Total Reward: 2214, Epsilon: 0.5160
# Episode 133/400, Total Reward: 2220, Epsilon: 0.5134
# Episode 134/400, Total Reward: 2228, Epsilon: 0.5108
# Episode 135/400, Total Reward: 2206, Epsilon: 0.5083
# Episode 136/400, Total Reward: 2221, Epsilon: 0.5058
# Episode 137/400, Total Reward: 2218, Epsilon: 0.5032
# Episode 138/400, Total Reward: 2229, Epsilon: 0.5007
# Episode 139/400, Total Reward: 2198, Epsilon: 0.4982
# Episode 140/400, Total Reward: 2178, Epsilon: 0.4957
# Episode 141/400, Total Reward: 2247, Epsilon: 0.4932
# Episode 142/400, Total Reward: 2146, Epsilon: 0.4908
# Episode 143/400, Total Reward: 2254, Epsilon: 0.4883
# Episode 144/400, Total Reward: 2226, Epsilon: 0.4859
# Episode 145/400, Total Reward: 2256, Epsilon: 0.4834
# Episode 146/400, Total Reward: 2234, Epsilon: 0.4810
# Episode 147/400, Total Reward: 2229, Epsilon: 0.4786
# Episode 148/400, Total Reward: 2239, Epsilon: 0.4762
# Episode 149/400, Total Reward: 2206, Epsilon: 0.4738
# Episode 150/400, Total Reward: 2203, Epsilon: 0.4715
# Episode 151/400, Total Reward: 2208, Epsilon: 0.4691
# Episode 152/400, Total Reward: 2163, Epsilon: 0.4668
# Episode 153/400, Total Reward: 2238, Epsilon: 0.4644
# Episode 154/400, Total Reward: 2183, Epsilon: 0.4621
# Episode 155/400, Total Reward: 2231, Epsilon: 0.4598
# Episode 156/400, Total Reward: 2249, Epsilon: 0.4575
# Episode 157/400, Total Reward: 2247, Epsilon: 0.4552
# Episode 158/400, Total Reward: 2245, Epsilon: 0.4529
# Episode 159/400, Total Reward: 2196, Epsilon: 0.4507
# Episode 160/400, Total Reward: 2248, Epsilon: 0.4484
# Episode 161/400, Total Reward: 2258, Epsilon: 0.4462
# Episode 162/400, Total Reward: 2127, Epsilon: 0.4440
# Episode 163/400, Total Reward: 2233, Epsilon: 0.4417
# Episode 164/400, Total Reward: 2244, Epsilon: 0.4395
# Episode 165/400, Total Reward: 2252, Epsilon: 0.4373
# Episode 166/400, Total Reward: 2267, Epsilon: 0.4351
# Episode 167/400, Total Reward: 2230, Epsilon: 0.4330
# Episode 168/400, Total Reward: 2273, Epsilon: 0.4308
# Episode 169/400, Total Reward: 2266, Epsilon: 0.4286
# Episode 170/400, Total Reward: 2184, Epsilon: 0.4265
# Episode 171/400, Total Reward: 2247, Epsilon: 0.4244
# Episode 172/400, Total Reward: 2178, Epsilon: 0.4223
# Episode 173/400, Total Reward: 2261, Epsilon: 0.4201
# Episode 174/400, Total Reward: 2239, Epsilon: 0.4180
# Episode 175/400, Total Reward: 2231, Epsilon: 0.4159
# Episode 176/400, Total Reward: 2189, Epsilon: 0.4139
# Episode 177/400, Total Reward: 2272, Epsilon: 0.4118
# Episode 178/400, Total Reward: 2229, Epsilon: 0.4097
# Episode 179/400, Total Reward: 2250, Epsilon: 0.4077
# Episode 180/400, Total Reward: 2277, Epsilon: 0.4057
# Episode 181/400, Total Reward: 2171, Epsilon: 0.4036
# Episode 182/400, Total Reward: 2169, Epsilon: 0.4016
# Episode 183/400, Total Reward: 2213, Epsilon: 0.3996
# Episode 184/400, Total Reward: 2231, Epsilon: 0.3976
# Episode 185/400, Total Reward: 2264, Epsilon: 0.3956
# Episode 186/400, Total Reward: 2239, Epsilon: 0.3936
# Episode 187/400, Total Reward: 2238, Epsilon: 0.3917
# Episode 188/400, Total Reward: 2253, Epsilon: 0.3897
# Episode 189/400, Total Reward: 2238, Epsilon: 0.3878
# Episode 190/400, Total Reward: 2210, Epsilon: 0.3858
# Episode 191/400, Total Reward: 2226, Epsilon: 0.3839
# Episode 192/400, Total Reward: 2147, Epsilon: 0.3820
# Episode 193/400, Total Reward: 2244, Epsilon: 0.3801
# Episode 194/400, Total Reward: 2260, Epsilon: 0.3782
# Episode 195/400, Total Reward: 2266, Epsilon: 0.3763
# Episode 196/400, Total Reward: 2247, Epsilon: 0.3744
# Episode 197/400, Total Reward: 2234, Epsilon: 0.3725
# Episode 198/400, Total Reward: 2252, Epsilon: 0.3707
# Episode 199/400, Total Reward: 2270, Epsilon: 0.3688
# Episode 200/400, Total Reward: 2230, Epsilon: 0.3670
# Episode 201/400, Total Reward: 2247, Epsilon: 0.3651
# Episode 202/400, Total Reward: 2001, Epsilon: 0.3633
# Episode 203/400, Total Reward: 2259, Epsilon: 0.3615
# Episode 204/400, Total Reward: 2251, Epsilon: 0.3597
# Episode 205/400, Total Reward: 2270, Epsilon: 0.3579
# Episode 206/400, Total Reward: 2244, Epsilon: 0.3561
# Episode 207/400, Total Reward: 2257, Epsilon: 0.3543
# Episode 208/400, Total Reward: 2225, Epsilon: 0.3525
# Episode 209/400, Total Reward: 2242, Epsilon: 0.3508
# Episode 210/400, Total Reward: 2243, Epsilon: 0.3490
# Episode 211/400, Total Reward: 2240, Epsilon: 0.3473
# Episode 212/400, Total Reward: 2211, Epsilon: 0.3455
# Episode 213/400, Total Reward: 2269, Epsilon: 0.3438
# Episode 214/400, Total Reward: 2257, Epsilon: 0.3421
# Episode 215/400, Total Reward: 2258, Epsilon: 0.3404
# Episode 216/400, Total Reward: 2254, Epsilon: 0.3387
# Episode 217/400, Total Reward: 2248, Epsilon: 0.3370
# Episode 218/400, Total Reward: 2264, Epsilon: 0.3353
# Episode 219/400, Total Reward: 2247, Epsilon: 0.3336
# Episode 220/400, Total Reward: 2269, Epsilon: 0.3320
# Episode 221/400, Total Reward: 2272, Epsilon: 0.3303
# Episode 222/400, Total Reward: 2192, Epsilon: 0.3286
# Episode 223/400, Total Reward: 2252, Epsilon: 0.3270
# Episode 224/400, Total Reward: 2264, Epsilon: 0.3254
# Episode 225/400, Total Reward: 2256, Epsilon: 0.3237
# Episode 226/400, Total Reward: 2255, Epsilon: 0.3221
# Episode 227/400, Total Reward: 2270, Epsilon: 0.3205
# Episode 228/400, Total Reward: 2247, Epsilon: 0.3189
# Episode 229/400, Total Reward: 2254, Epsilon: 0.3173
# Episode 230/400, Total Reward: 2253, Epsilon: 0.3157
# Episode 231/400, Total Reward: 2271, Epsilon: 0.3141
# Episode 232/400, Total Reward: 2213, Epsilon: 0.3126
# Episode 233/400, Total Reward: 2273, Epsilon: 0.3110
# Episode 234/400, Total Reward: 2263, Epsilon: 0.3095
# Episode 235/400, Total Reward: 2251, Epsilon: 0.3079
# Episode 236/400, Total Reward: 2253, Epsilon: 0.3064
# Episode 237/400, Total Reward: 2235, Epsilon: 0.3048
# Episode 238/400, Total Reward: 2236, Epsilon: 0.3033
# Episode 239/400, Total Reward: 2261, Epsilon: 0.3018
# Episode 240/400, Total Reward: 2273, Epsilon: 0.3003
# Episode 241/400, Total Reward: 2262, Epsilon: 0.2988
# Episode 242/400, Total Reward: 2104, Epsilon: 0.2973
# Episode 243/400, Total Reward: 2261, Epsilon: 0.2958
# Episode 244/400, Total Reward: 2266, Epsilon: 0.2943
# Episode 245/400, Total Reward: 2266, Epsilon: 0.2929
# Episode 246/400, Total Reward: 2271, Epsilon: 0.2914
# Episode 247/400, Total Reward: 2252, Epsilon: 0.2899
# Episode 248/400, Total Reward: 2270, Epsilon: 0.2885
# Episode 249/400, Total Reward: 2257, Epsilon: 0.2870
# Episode 250/400, Total Reward: 2277, Epsilon: 0.2856
# Episode 251/400, Total Reward: 2264, Epsilon: 0.2842
# Episode 252/400, Total Reward: 2204, Epsilon: 0.2828
# Episode 253/400, Total Reward: 2277, Epsilon: 0.2813
# Episode 254/400, Total Reward: 2267, Epsilon: 0.2799
# Episode 255/400, Total Reward: 2248, Epsilon: 0.2785
# Episode 256/400, Total Reward: 2269, Epsilon: 0.2771
# Episode 257/400, Total Reward: 2266, Epsilon: 0.2758
# Episode 258/400, Total Reward: 2234, Epsilon: 0.2744
# Episode 259/400, Total Reward: 2258, Epsilon: 0.2730
# Episode 260/400, Total Reward: 2264, Epsilon: 0.2716
# Episode 261/400, Total Reward: 2278, Epsilon: 0.2703
# Episode 262/400, Total Reward: 2136, Epsilon: 0.2689
# Episode 263/400, Total Reward: 2250, Epsilon: 0.2676
# Episode 264/400, Total Reward: 2265, Epsilon: 0.2663
# Episode 265/400, Total Reward: 2267, Epsilon: 0.2649
# Episode 266/400, Total Reward: 2251, Epsilon: 0.2636
# Episode 267/400, Total Reward: 2259, Epsilon: 0.2623
# Episode 268/400, Total Reward: 2243, Epsilon: 0.2610
# Episode 269/400, Total Reward: 2258, Epsilon: 0.2597
# Episode 270/400, Total Reward: 2258, Epsilon: 0.2584
# Episode 271/400, Total Reward: 2266, Epsilon: 0.2571
# Episode 272/400, Total Reward: 2097, Epsilon: 0.2558
# Episode 273/400, Total Reward: 2277, Epsilon: 0.2545
# Episode 274/400, Total Reward: 2263, Epsilon: 0.2532
# Episode 275/400, Total Reward: 2264, Epsilon: 0.2520
# Episode 276/400, Total Reward: 2271, Epsilon: 0.2507
# Episode 277/400, Total Reward: 2259, Epsilon: 0.2495
# Episode 278/400, Total Reward: 2259, Epsilon: 0.2482
# Episode 279/400, Total Reward: 2277, Epsilon: 0.2470
# Episode 280/400, Total Reward: 2268, Epsilon: 0.2457
# Episode 281/400, Total Reward: 2266, Epsilon: 0.2445
# Episode 282/400, Total Reward: 2151, Epsilon: 0.2433
# Episode 283/400, Total Reward: 2265, Epsilon: 0.2421
# Episode 284/400, Total Reward: 2263, Epsilon: 0.2409
# Episode 285/400, Total Reward: 2272, Epsilon: 0.2397
# Episode 286/400, Total Reward: 2273, Epsilon: 0.2385
# Episode 287/400, Total Reward: 2269, Epsilon: 0.2373
# Episode 288/400, Total Reward: 2266, Epsilon: 0.2361
# Episode 289/400, Total Reward: 2263, Epsilon: 0.2349
# Episode 290/400, Total Reward: 2257, Epsilon: 0.2337
# Episode 291/400, Total Reward: 2269, Epsilon: 0.2326
# Episode 292/400, Total Reward: 2055, Epsilon: 0.2314
# Episode 293/400, Total Reward: 2270, Epsilon: 0.2302
# Episode 294/400, Total Reward: 2277, Epsilon: 0.2291
# Episode 295/400, Total Reward: 2278, Epsilon: 0.2279
# Episode 296/400, Total Reward: 2262, Epsilon: 0.2268
# Episode 297/400, Total Reward: 2265, Epsilon: 0.2257
# Episode 298/400, Total Reward: 2275, Epsilon: 0.2245
# Episode 299/400, Total Reward: 2265, Epsilon: 0.2234
# Episode 300/400, Total Reward: 2273, Epsilon: 0.2223
# Episode 301/400, Total Reward: 2274, Epsilon: 0.2212
# Episode 302/400, Total Reward: 2099, Epsilon: 0.2201
# Episode 303/400, Total Reward: 2270, Epsilon: 0.2190
# Episode 304/400, Total Reward: 2262, Epsilon: 0.2179
# Episode 305/400, Total Reward: 2262, Epsilon: 0.2168
# Episode 306/400, Total Reward: 2279, Epsilon: 0.2157
# Episode 307/400, Total Reward: 2254, Epsilon: 0.2146
# Episode 308/400, Total Reward: 2284, Epsilon: 0.2136
# Episode 309/400, Total Reward: 2264, Epsilon: 0.2125
# Episode 310/400, Total Reward: 2274, Epsilon: 0.2114
# Episode 311/400, Total Reward: 2281, Epsilon: 0.2104
# Episode 312/400, Total Reward: 2231, Epsilon: 0.2093
# Episode 313/400, Total Reward: 2281, Epsilon: 0.2083
# Episode 314/400, Total Reward: 2258, Epsilon: 0.2072
# Episode 315/400, Total Reward: 2279, Epsilon: 0.2062
# Episode 316/400, Total Reward: 2273, Epsilon: 0.2052
# Episode 317/400, Total Reward: 2279, Epsilon: 0.2041
# Episode 318/400, Total Reward: 2276, Epsilon: 0.2031
# Episode 319/400, Total Reward: 2267, Epsilon: 0.2021
# Episode 320/400, Total Reward: 2278, Epsilon: 0.2011
# Episode 321/400, Total Reward: 2283, Epsilon: 0.2001
# Episode 322/400, Total Reward: 2154, Epsilon: 0.1991
# Episode 323/400, Total Reward: 2261, Epsilon: 0.1981
# Episode 324/400, Total Reward: 2266, Epsilon: 0.1971
# Episode 325/400, Total Reward: 2279, Epsilon: 0.1961
# Episode 326/400, Total Reward: 2270, Epsilon: 0.1951
# Episode 327/400, Total Reward: 2260, Epsilon: 0.1942
# Episode 328/400, Total Reward: 2279, Epsilon: 0.1932
# Episode 329/400, Total Reward: 2267, Epsilon: 0.1922
# Episode 330/400, Total Reward: 2277, Epsilon: 0.1913
# Episode 331/400, Total Reward: 2257, Epsilon: 0.1903
# Episode 332/400, Total Reward: 2184, Epsilon: 0.1893
# Episode 333/400, Total Reward: 2275, Epsilon: 0.1884
# Episode 334/400, Total Reward: 2280, Epsilon: 0.1875
# Episode 335/400, Total Reward: 2274, Epsilon: 0.1865
# Episode 336/400, Total Reward: 2273, Epsilon: 0.1856
# Episode 337/400, Total Reward: 2273, Epsilon: 0.1847
# Episode 338/400, Total Reward: 2276, Epsilon: 0.1837
# Episode 339/400, Total Reward: 2272, Epsilon: 0.1828
# Episode 340/400, Total Reward: 2260, Epsilon: 0.1819
# Episode 341/400, Total Reward: 2242, Epsilon: 0.1810
# Episode 342/400, Total Reward: 2176, Epsilon: 0.1801
# Episode 343/400, Total Reward: 2281, Epsilon: 0.1792
# Episode 344/400, Total Reward: 2282, Epsilon: 0.1783
# Episode 345/400, Total Reward: 2271, Epsilon: 0.1774
# Episode 346/400, Total Reward: 2280, Epsilon: 0.1765
# Episode 347/400, Total Reward: 2264, Epsilon: 0.1756
# Episode 348/400, Total Reward: 2276, Epsilon: 0.1748
# Episode 349/400, Total Reward: 2280, Epsilon: 0.1739
# Episode 350/400, Total Reward: 2278, Epsilon: 0.1730
# Episode 351/400, Total Reward: 2274, Epsilon: 0.1721
# Episode 352/400, Total Reward: 2151, Epsilon: 0.1713
# Episode 353/400, Total Reward: 2280, Epsilon: 0.1704
# Episode 354/400, Total Reward: 2267, Epsilon: 0.1696
# Episode 355/400, Total Reward: 2277, Epsilon: 0.1687
# Episode 356/400, Total Reward: 2257, Epsilon: 0.1679
# Episode 357/400, Total Reward: 2270, Epsilon: 0.1670
# Episode 358/400, Total Reward: 2282, Epsilon: 0.1662
# Episode 359/400, Total Reward: 2267, Epsilon: 0.1654
# Episode 360/400, Total Reward: 2276, Epsilon: 0.1646
# Episode 361/400, Total Reward: 2270, Epsilon: 0.1637
# Episode 362/400, Total Reward: 2145, Epsilon: 0.1629
# Episode 363/400, Total Reward: 2279, Epsilon: 0.1621
# Episode 364/400, Total Reward: 2283, Epsilon: 0.1613
# Episode 365/400, Total Reward: 2282, Epsilon: 0.1605
# Episode 366/400, Total Reward: 2279, Epsilon: 0.1597
# Episode 367/400, Total Reward: 2267, Epsilon: 0.1589
# Episode 368/400, Total Reward: 2279, Epsilon: 0.1581
# Episode 369/400, Total Reward: 2279, Epsilon: 0.1573
# Episode 370/400, Total Reward: 2278, Epsilon: 0.1565
# Episode 371/400, Total Reward: 2273, Epsilon: 0.1557
# Episode 372/400, Total Reward: 2135, Epsilon: 0.1549
# Episode 373/400, Total Reward: 2276, Epsilon: 0.1542
# Episode 374/400, Total Reward: 2281, Epsilon: 0.1534
# Episode 375/400, Total Reward: 2280, Epsilon: 0.1526
# Episode 376/400, Total Reward: 2276, Epsilon: 0.1519
# Episode 377/400, Total Reward: 2273, Epsilon: 0.1511
# Episode 378/400, Total Reward: 2273, Epsilon: 0.1504
# Episode 379/400, Total Reward: 2284, Epsilon: 0.1496
# Episode 380/400, Total Reward: 2270, Epsilon: 0.1489
# Episode 381/400, Total Reward: 2272, Epsilon: 0.1481
# Episode 382/400, Total Reward: 2149, Epsilon: 0.1474
# Episode 383/400, Total Reward: 2278, Epsilon: 0.1466
# Episode 384/400, Total Reward: 2280, Epsilon: 0.1459
# Episode 385/400, Total Reward: 2274, Epsilon: 0.1452
# Episode 386/400, Total Reward: 2280, Epsilon: 0.1444
# Episode 387/400, Total Reward: 2277, Epsilon: 0.1437
# Episode 388/400, Total Reward: 2280, Epsilon: 0.1430
# Episode 389/400, Total Reward: 2284, Epsilon: 0.1423
# Episode 390/400, Total Reward: 2285, Epsilon: 0.1416
# Episode 391/400, Total Reward: 2277, Epsilon: 0.1409
# Episode 392/400, Total Reward: 2165, Epsilon: 0.1402
# Episode 393/400, Total Reward: 2278, Epsilon: 0.1395
# Episode 394/400, Total Reward: 2277, Epsilon: 0.1388
# Episode 395/400, Total Reward: 2279, Epsilon: 0.1381
# Episode 396/400, Total Reward: 2278, Epsilon: 0.1374
# Episode 397/400, Total Reward: 2279, Epsilon: 0.1367
# Episode 398/400, Total Reward: 2281, Epsilon: 0.1360
# Episode 399/400, Total Reward: 2279, Epsilon: 0.1353
# Episode 400/400, Total Reward: 2267, Epsilon: 0.1347
# Training completed!

# %%
import torch
import matplotlib.pyplot as plt

# Function to select action using the trained policy (no exploration)
def select_action_trained(state):
    state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)  # Move state to GPU
    with torch.no_grad():  # No gradient calculation needed for testing
        q_values = q_network(state_tensor)
        return q_values.argmax().item()  # Action with the highest Q-value

# Test the trained agent for a single episode and plot the disk positions
def test_trained_agent():
    state = env.reset()  # Reset the environment to start a new episode
    total_reward = 0
    steps = 0
    max_steps = 50  # Limit the steps per episode for testing

    # List to store the disk positions for plotting
    disk1_positions = []
    disk2_positions = []

    print("Testing the trained agent...")

    for step in range(max_steps):
        action = select_action_trained(state)  # Select the best action using the trained model
        next_state, reward, done = env.step(action)  # Apply the action in the environment
        total_reward += reward  # Accumulate the reward
        state = next_state  # Move to the next state
        steps += 1

        # Store disk positions for plotting
        disk1_positions.append(state[:2])  # Disk 1 position (x1, y1)
        disk2_positions.append(state[2:])  # Disk 2 position (x2, y2)

        # Print the details of each step
        print(f"Step: {steps}, Action: {action}, Reward: {reward}, Total Reward: {total_reward}")

        if done:
            break  # End the episode if the environment signals it's done

    # Print final positions of the disks
    print(f"Final position of Disk 1: {disk1_positions[-1]}")
    print(f"Final position of Disk 2: {disk2_positions[-1]}")
    print(f"Test completed. Total Reward after {steps} steps: {total_reward}")

    # Plot the final positions of the disks and the dots
    plot_disks_and_dots(disk1_positions[-1], disk2_positions[-1])

# Function to plot the disk positions and the dots
def plot_disks_and_dots(disk1_pos, disk2_pos):
    fig, ax = plt.subplots()

    # Plot the dots in the grid
    dots = np.array(env.dots)
    ax.scatter(dots[:, 0], dots[:, 1], color='blue', label="Dots")

    # Plot the disks as circles
    disk1_circle = plt.Circle(disk1_pos, env.disk_radius, color='red', fill=False, label="Disk 1")
    disk2_circle = plt.Circle(disk2_pos, env.disk_radius, color='green', fill=False, label="Disk 2")
    ax.add_artist(disk1_circle)
    ax.add_artist(disk2_circle)

    # Set the limits and labels for the plot
    ax.set_xlim(0, 4)
    ax.set_ylim(0, 4)
    ax.set_title('Final Disk Positions and Dots')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.legend()

    plt.gca().set_aspect('equal', adjustable='box')
    plt.grid(True)
    plt.show()

# Run the test
test_trained_agent()
# Out:
# Testing the trained agent...
# Step: 1, Action: 19, Reward: 19, Total Reward: 19
# Step: 2, Action: 19, Reward: 20, Total Reward: 39
# Step: 3, Action: 19, Reward: 20, Total Reward: 59
# Step: 4, Action: 17, Reward: 21, Total Reward: 80
# Step: 5, Action: 17, Reward: 22, Total Reward: 102
# Step: 6, Action: 16, Reward: 23, Total Reward: 125
# Step: 7, Action: 13, Reward: 22, Total Reward: 147
# Step: 8, Action: 19, Reward: 23, Total Reward: 170
# Step: 9, Action: 19, Reward: 23, Total Reward: 193
# Step: 10, Action: 13, Reward: 23, Total Reward: 216
# Step: 11, Action: 6, Reward: 23, Total Reward: 239
# Step: 12, Action: 17, Reward: 23, Total Reward: 262
# Step: 13, Action: 24, Reward: 23, Total Reward: 285
# Step: 14, Action: 13, Reward: 23, Total Reward: 308
# Step: 15, Action: 6, Reward: 23, Total Reward: 331
# Step: 16, Action: 17, Reward: 23, Total Reward: 354
# Step: 17, Action: 24, Reward: 23, Total Reward: 377
# Step: 18, Action: 13, Reward: 23, Total Reward: 400
# Step: 19, Action: 6, Reward: 23, Total Reward: 423
# Step: 20, Action: 17, Reward: 23, Total Reward: 446
# Step: 21, Action: 24, Reward: 23, Total Reward: 469
# Step: 22, Action: 13, Reward: 23, Total Reward: 492
# Step: 23, Action: 6, Reward: 23, Total Reward: 515
# Step: 24, Action: 17, Reward: 23, Total Reward: 538
# Step: 25, Action: 24, Reward: 23, Total Reward: 561
# Step: 26, Action: 13, Reward: 23, Total Reward: 584
# Step: 27, Action: 6, Reward: 23, Total Reward: 607
# Step: 28, Action: 17, Reward: 23, Total Reward: 630
# Step: 29, Action: 24, Reward: 23, Total Reward: 653
# Step: 30, Action: 13, Reward: 23, Total Reward: 676
# Step: 31, Action: 6, Reward: 23, Total Reward: 699
# Step: 32, Action: 17, Reward: 23, Total Reward: 722
# Step: 33, Action: 24, Reward: 23, Total Reward: 745
# Step: 34, Action: 13, Reward: 23, Total Reward: 768
# Step: 35, Action: 6, Reward: 23, Total Reward: 791
# Step: 36, Action: 17, Reward: 23, Total Reward: 814
# Step: 37, Action: 24, Reward: 23, Total Reward: 837
# Step: 38, Action: 13, Reward: 23, Total Reward: 860
# Step: 39, Action: 6, Reward: 23, Total Reward: 883
# Step: 40, Action: 17, Reward: 23, Total Reward: 906
# Step: 41, Action: 24, Reward: 23, Total Reward: 929
# Step: 42, Action: 13, Reward: 23, Total Reward: 952
# Step: 43, Action: 6, Reward: 23, Total Reward: 975
# Step: 44, Action: 17, Reward: 23, Total Reward: 998
# Step: 45, Action: 24, Reward: 23, Total Reward: 1021
# Step: 46, Action: 13, Reward: 23, Total Reward: 1044
# Step: 47, Action: 6, Reward: 23, Total Reward: 1067
# Step: 48, Action: 17, Reward: 23, Total Reward: 1090
# Step: 49, Action: 24, Reward: 23, Total Reward: 1113
# Step: 50, Action: 13, Reward: 23, Total Reward: 1136
# Final position of Disk 1: [1.2 1.8]
# Final position of Disk 2: [2.3 1.9]
# Test completed. Total Reward after 50 steps: 1136

# %%
#test

# Function to plot the disk positions and the dots
def plot_disks_and_dots(disk1_pos, disk2_pos):
    fig, ax = plt.subplots()

    # Plot the dots in the grid
    dots = np.array(env.dots)
    ax.scatter(dots[:, 0], dots[:, 1], color='blue', label="Dots")

    # Plot the disks as circles
    disk1_circle = plt.Circle(disk1_pos, env.disk_radius, color='red', fill=False, label="FOV 1")
    disk2_circle = plt.Circle(disk2_pos, env.disk_radius, color='green', fill=False, label="FOV 2")
    ax.add_artist(disk1_circle)
    ax.add_artist(disk2_circle)

    # Set the limits and labels for the plot
    ax.set_xlim(0, 4)
    ax.set_ylim(0, 4)
    ax.set_title('Env. Drone FOV & Dots')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.legend()

    plt.gca().set_aspect('equal', adjustable='box')
    plt.grid(True)
    plt.show()
plot_disks_and_dots([1.2, 2.8], [2.8, 1.3])
